# %%
import json
from pprint import pprint
import pandas as pd
import numpy as np

# %%
data = []
with open('/home/julia/Загрузки/Telegram Desktop/552670aa4eae356bf4d0d11c.jsonl') as raw_data:
    for line in raw_data:
        data.append(json.loads(line))
#pprint(data)
df = pd.DataFrame(data)
df['created'] = pd.to_datetime(df['created'])
df =  df.sort_values('created' )
#df['created'] = df.created.astype(str)
df['word'] = df.word.str.join(',')
print(type(df.get_value(3,'title')))
df['day'] = df.created.dt.day
df['hour'] = df.created.dt.hour
df['minute'] = df.created.dt.minute
df['date'] = df['day'].map(str) + "-" + df['hour'].map(str) + "-" + df['minute'].map(str)
#z = (np.unique(dff[['word']].values))
#z2 = len(sorted(set((",".join(z).split(",")))))
df
# Out:
# <class 'str'>
#                 created language                             source  \
# 100 2017-09-15 11:01:44       ru                Транспортный бизнес
# 264 2017-09-15 11:03:09       ru                            2000.ua
# 266 2017-09-15 11:03:36       uk                           ЕраМедіа
# 99  2017-09-15 11:04:23       ru                             ОстроВ
# 265 2017-09-15 11:05:11       ru                            2000.ua
# 97  2017-09-15 11:13:05       ru  06239.com.ua Покровск и Мирноград
# 98  2017-09-15 11:13:13       uk                            Insider
# 96  2017-09-15 11:13:52       ru                         ПрессОрг24
# 249 2017-09-15 11:14:22       ru                         ИнформБюро
# 250 2017-09-15 11:14:56       ru                     Репортер.dn.ua
# 251 2017-09-15 11:16:26       ru                            DailyUA
# 253 2017-09-15 11:16:49       ru                        Times.dn.ua
# 252 2017-09-15 11:16:50       ru                        Times.dn.ua
# 254 2017-09-15 11:32:10       ru      Українські національні новини
# 255 2017-09-15 11:33:03       uk      Українські національні новини
# 267 2017-09-15 12:01:42       ru                   Новости Донбасса
# 244 2017-09-15 12:19:29       ru       Центр Транспортных Стратегий
# 247 2017-09-15 12:22:29       uk                    Новости INTV.ua
# 239 2017-09-15 12:23:49       uk                   Ранок з Україною
# 245 2017-09-15 12:25:37       ru                    Знамя индустрии
# 248 2017-09-15 12:26:27       ru                     InfoResist.org
# 246 2017-09-15 12:30:34       ru               Люстратор. Запорожье
# 263 2017-09-15 12:33:23       ru                          Страна.ua
# 262 2017-09-15 12:33:47       ru                      Порты Украины
# 257 2017-09-15 12:37:22       uk    Корпоративний сайт «Київенерго»
# 256 2017-09-15 12:37:23       ru    Корпоративний сайт «Київенерго»
# 258 2017-09-15 12:40:51       ru                  Українські Новини
# 260 2017-09-15 13:02:35       ru                         Donbass.UA
# 259 2017-09-15 13:03:00       ru                    Деловая столица
# 261 2017-09-15 13:03:37       ru                       ФедералПресс
# ..                  ...      ...                                ...
# 4   2017-09-18 09:43:06       ru                        NewsNetwork
# 185 2017-09-18 09:45:12       ru          Вибори в Україні та світі
# 184 2017-09-18 09:45:55       ru                              Hyser
# 187 2017-09-18 09:48:32       ru                   Mediaexpert Life
# 186 2017-09-18 09:48:36       ru                    Kramatorsk Post
# 214 2017-09-18 09:50:18       ru                           Белрынок
# 188 2017-09-18 09:51:26       ru                 NEWS FOR BREAKFAST
# 219 2017-09-18 09:51:32       ru                        ARENA.PRESS
# 199  енергетичн,газ,рос,компан,невоєн,збр,має,політ...   18    10       5
# 198  грн,контракт,период,составил,акц,сделок,украин...   18    10       5
# 201  дтэк,тонн,тыс,антрацит,тэс,балкер,станц,украин...   18    10       8
# 34   девушк,механизм,профессионал,ремонт,цех,охотн,...   18    10      10
# 215  вугілл,тес,тис,тонн,антрацит,дтек,придніпровсь...   18    10      13
# 7    дтэк,тонн,тыс,антрацит,тэс,украин,балкер,станц...   18    10      15
# 8    тыс,тонн,украин,балкер,порт,южн,антрацит,судн,...   18    10      20
# 1    тонн,тыс,антрацит,дтэк,парт,тэс,угл,южн,балкер...   18    10      30
# 0    угл,тонн,тыс,парт,юар,антрацит,объем,украин,дт...   18    10      30
# 10   угл,газ,украин,отопительн,сезон,запас,риск,про...   18    10      31
# 224  антрацит,африканськ,дтек,південн,енергохолдинг...   18    10      57
#
#          date
# 100   15-11-1
# 264   15-11-3
# 266   15-11-3
# 99    15-11-4
# 265   15-11-5
# 97   15-11-13
# 98   15-11-13
# 96   15-11-13
# 249  15-11-14
# 250  15-11-14
# 251  15-11-16
# 253  15-11-16
# 252  15-11-16
# 254  15-11-32
# 255  15-11-33
# 267   15-12-1
# 244  15-12-19
# 247  15-12-22
# 239  15-12-23
# 245  15-12-25
# 248  15-12-26
# 246  15-12-30
# 263  15-12-33
# 262  15-12-33
# 257  15-12-37
# 256  15-12-37
# 258  15-12-40
# 260   15-13-2
# 259   15-13-3
# 261   15-13-3
# ..        ...
# 4     18-9-43
# 185   18-9-45
# 184   18-9-45
# 187   18-9-48
# 186   18-9-48
# 214   18-9-50
# 188   18-9-51
# 219   18-9-51
# 189   18-9-51
# 220   18-9-52
# 222   18-9-52
# 221   18-9-53
# 197   18-9-53
# 9     18-9-55
# 213   18-9-56
# 225   18-9-57
# 5     18-10-2
# 6     18-10-4
# 200   18-10-4
# 199   18-10-5
# 198   18-10-5
# 201   18-10-8
# 34   18-10-10
# 215  18-10-13
# 7    18-10-15
# 8    18-10-20
# 1    18-10-30
# 0    18-10-30
# 10   18-10-31
# 224  18-10-57
#
# [295 rows x 11 columns]

# %% [markdown]
# Импортим документы,переводим в датафрейм,чтобы было удобно работать и приятно смотреть. Предобрабатываем ячейки времени и токенов для дальнейшей работы.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(min_df=5, max_features=10000, ngram_range=(1, 2))
vz = vectorizer.fit_transform(df['word'])
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
tfidf = pd.DataFrame(columns=['tfidf']).from_dict(dict(tfidf), orient='index')
tfidf.columns = ['tfidf']
#tfidf.sort_values(by=['tfidf'], ascending=True).head(30)

# %% [markdown]
# Переводим наши тексты в векторное пространство токенов,чтобы далее использовать меру этого пространства для оценки близости при кластеризации.

# %%
from sklearn.cluster import MiniBatchKMeans

num_clusters = 27
kmeans_model = MiniBatchKMeans(n_clusters=num_clusters, init='k-means++', n_init=1, 
                         init_size=1000, batch_size=1000, verbose=False, max_iter=1000)
kmeans = kmeans_model.fit(vz)
kmeans_clusters = kmeans.predict(vz)
kmeans_distances = kmeans.transform(vz)

# %% [markdown]
# Вот и первый кластеризатор: kmeans, которому скармливаем наше векторное представление.(для лучшего эффекта кластеризации стоит запустить несколько раз,так сказать ,дать возможность разогреться - совет из документации алгоритма в библиотеке)

# %%
for i, desc in enumerate(df.title):
    if(i < 295):
        if kmeans_clusters[i] == 9:
            print("Cluster " + str(kmeans_clusters[i]) + ": " + desc + 
                  "(distance: " + str(kmeans_distances[i][kmeans_clusters[i]]) + ")")
            print('---')
# Out:
# Cluster 9: Под эгидой РП РЭК объединили 5 предприятий с внешним управлением(distance: 0.596146064976)
# ---
# Cluster 9: "ДНР" объединила в одну компанию захваченные предприятия Ахметова(distance: 0.466730016403)
# ---
# Cluster 9: Что "ДНР" сделала со всеми предприятиями Ахметова(distance: 0.163917796158)
# ---
# Cluster 9: Что "ДНР" сделала со всеми предприятиями Ахметова(distance: 0.163917796158)
# ---
# Cluster 9: Что "ДНР" сделала со всеми предприятиями Ахметова(distance: 0.163917796158)
# ---
# Cluster 9: Что "ДНР" сделала со всеми предприятиями Ахметова(distance: 0.242494562859)
# ---

# %% [markdown]
# Функция-костыль(зато очень наглядная),можно посмотреть,что попало в каждый из кластеров, не вывожу все кластеры подряд,потому что это никакой ценности не имеет,только место будет занимать,можно просто ввести парочку номеров кластеров и оценить их внутренний мир)

# %%
import lda
from sklearn.feature_extraction.text import CountVectorizer

# %%
import logging
logging.getLogger("lda").setLevel(logging.WARNING)

# %%
cvectorizer = CountVectorizer(min_df=4, max_features=10000, ngram_range=(1,2))
cvz = cvectorizer.fit_transform(df['word'])

n_topics = 32

n_iter = 2000
lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)
# Out:
# WARNING:lda:all zero row in document-term matrix found

# %% [markdown]
# Используем похожий подход с векторным пространством, только теперь с помощью CountVectorizer, и скармливаем это LDA- хитрому алгоритму,который и сам может рассматриваться  как кластеризатор, но оказывается лучше его использовать для того чтобы выделить тематические фичи,а не кластеры.

# %%
from sklearn import preprocessing 
from functools import reduce
stand_df = preprocessing.scale(df['day'])
X_all  = np.hstack((X_topics,stand_df.reshape((X_topics.shape[0],1)) ))
kmeans1 = kmeans_model.fit(X_all)
kmeans_clusters1 = kmeans1.predict(X_all)
kmeans_distances1 = kmeans1.transform(X_all)
#print(kmeans_distances)
#print(kmeans_clusters)
d = dict()
l = 1


for i, desc in enumerate(df.title):
    #ar = reduce(lambda x1, x2: x1*x2, tuple(np.argwhere(kmeans_distances == np.min(kmeans_distances[i,]))[0]))
     # right
    if(i < 295):
        num = 8
        if kmeans_clusters1[i] == num:
            if l > kmeans_distances1[i][kmeans_clusters1[i]]:
                l = kmeans_distances1[i][kmeans_clusters1[i]]  
            d['Cluster' + str(kmeans_clusters1[i])] = "distance:  " + str(l)+ "   "+ df.iloc[i]['text']
            print("Cluster " + str(kmeans_clusters1[i]) + ": " + desc + 
                  "(distance: " + str(kmeans_distances1[i][kmeans_clusters1[i]]) + ")")
            print('---')
print("Cluster " + str(num) + "   " + str(d.get('Cluster' + str(num))))
#print(d)
# Out:
# Cluster 8: ДТЕК Енерго направить більше 8 млрд грн на розвиток виробництва у 2017 році(distance: 0.299107868398)
# ---
# Cluster 8: ДТЕК Енерго направить більше 8 млрд грн на розвиток виробництва 2017 року(distance: 0.144297582029)
# ---
# Cluster 8: ДТЕК Енерго спрямує понад 8 млрд грн на розвиток виробництва 2017 року(distance: 0.162759807976)
# ---
# Cluster 8: Неаудированные консолидированные финансовые результаты ДТЭК Энерго за 6 месяцев 2017 года(distance: 0.296063312169)
# ---
# Cluster 8: На что энергокомпания Ахметова потратила 3,6 млрд гривень(distance: 0.234334593556)
# ---
# Cluster 8   distance:  0.144297582029   За шесть месяцев 2017 года ДТЭК вложил 3,6 млрд грн в капитальные инвестиции: увеличение добычи газового угля и переоборудование энергоблоков
#
# ДТЭК Энерго получила чистый убыток 1 млрд грн по итогам первого полугодия 2017 года. Об этом сообщает пресс-служба со ссылкой на неаудированную отчетность компании.
#
# По сравнению с І полугодием 2016 года, у компании выросла себестоимость производства на 8% или 4,4 млрд грн. Также, чтобы перекрыть утрату контроля над активами в ОРДЛО, компании пришлось на 64% увеличить капитальные инвестиции в 2017 году. ДТЭК Энерго вложила 3,6 млрд грн в увеличение добычи газового угля и перевод двух энергоблоков Приднепровской ТЭС с антрацитовых марок угля на газовые.
#
# "Компания сфокусировалась на инвестиционных проектах, которые направлены на увеличение добычи газовых марок угля и переводе энергоблоков ТЭС с антрацитов на эту марку угля... В целом по 2017 году ДТЭК Энерго планирует направить более 8 млрд грн на потребности производства", — сказал генеральный директор ДТЭК Энерго Дмитрий Сахарук.
#
# За восемь месяцев 2017 года Украины снизила добычу рядового угля на 9,4% (на 2,455 млн тонн) по сравнению с аналогичным периодом 2016 года — до 23,592 млн тонн.
#
# В 2016 году Украина увеличила добычу рядового угля на 2,8% (на 1,119 млн тонн) по сравнению с 2015 годом — до 40 млн 864,1 тыс. тонн.
#
# Напомним, из-за торговой блокады НКТ Украина лишилась легально добытого украинского антрацита. Теперь 100% этого топлива нужно импортировать из России, ЮАР, США. Для своих станций ДТЭК ввозит около 100 тыс. тонн антрацита со своих ростовских шахт, а также импортирует 225 тыс. тонн из ЮАР.
#
# По материалам: "Дело"
# /usr/local/lib/python3.4/dist-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, _DataConversionWarning)

# %% [markdown]
# Вот на этом этапе мы строим модель второго уровня,т.е. стандартизируем нашу матрицу с фичами из LDA и конкатенируем её со днём публикации статьи и опять скарпливаем это kmeans + приятный бонус: репрезентативный документ(правда совсем не pythonic way)

# %%
from sklearn.cluster import AffinityPropagation
af_pr_model = AffinityPropagation(damping=0.5, max_iter=1000, convergence_iter=5, preference=[-1,-2,-3])
affin_m = af_pr_model.fit(X_all)
affin_m_clusters = af_pr_model.predict(X_all)
print(len(af_pr_model.cluster_centers_indices_))
for i, desc in enumerate(df.title):
    if(i < 295):
        if affin_m_clusters[i] == 2:
            print("Cluster " + str(affin_m_clusters[i]) + ": " + desc )
            print('---')
# Out:
# 31
# Cluster 2: Под эгидой РП РЭК объединили 5 предприятий с внешним управлением
# ---
# Cluster 2: В ДНР пять национализированных украинских предприятий объединили в одну энергетическую компанию
# ---
# Cluster 2: В "ДНР" из "отжатых" у Ахметова предприятий создали "единую энергопоставляющую компанию"
# ---
# Cluster 2: Оккупационные "власти" ОРДО объединили в одну компанию пять "отжатых" у Ахметова предприятий
# ---
# Cluster 2: "ДНР" объединила в одну компанию захваченные предприятия Ахметова
# ---
# Cluster 2: В "ДНР" создали свою "единую энергопоставляющую компанию"
# ---
# Cluster 2: "ДНР" объединила в одну компанию захваченные предприятия Ахметова
# ---

# %% [markdown]
# Опять таки модель второго уровня.Алгоритм,который делает,что и требовалось в ТЗ. Самостоятельно выбирает количество кластеров в зависимости от связности damping и preference. Кажется preference можно очень классно настроить,но инфы необходимой пока что не нашла.

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=100, random_state=0,algorithm='arpack')
svd_tfidf = svd.fit_transform(vz)
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)
tsne_tfidf = tsne_model.fit_transform(svd_tfidf)
tsne_lda = tsne_model.fit_transform(X_topics)
tsne_kmeans = tsne_model.fit_transform(kmeans_distances1)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 295 / 295
# [t-SNE] Mean sigma: 0.538845
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 2.055220
# [t-SNE] Error after 425 iterations: 2.055220
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 295 / 295
# [t-SNE] Mean sigma: 0.280417
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.987146
# [t-SNE] Error after 500 iterations: 1.987146
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 295 / 295
# [t-SNE] Mean sigma: 0.374860
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 1.765538
# [t-SNE] Error after 500 iterations: 1.765538

# %% [markdown]
# Штука ,которая помогает плотить, уменьшает размерность матрицы

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook
colormap = np.array(["#6d8dca", "#69de53", "#723bca", "#c3e14c", "#c84dc9", "#68af4e", "#6e6cd5",
"#e3be38", "#4e2d7c", "#5fdfa8", "#d34690", "#3f6d31", "#d44427", "#7fcdd8", "#cb4053", "#5e9981",
"#803a62", "#9b9e39", "#c88cca", "#e1c37b", "#34223b", "#bdd8a3", "#6e3326", "#cfbdce", "#d07d3c",
"#52697d", "#7d6d33", "#d27c88", "#36422b", "#b68f79", "#7fff00", "#ffa500", "#ff1493", "#fac205"])

plot_kmeans = bp.figure(plot_width=700, plot_height=600, title="KMeans clustering of the news",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

# %%
kmeans_df = pd.DataFrame(tsne_kmeans, columns=['x', 'y'])
kmeans_df['cluster'] = kmeans_clusters1
kmeans_df['text'] = df['text']
kmeans_df['title'] = df['title']

# %%
plot_kmeans.scatter(x='x', y='y', 
                    color=colormap[kmeans_clusters1], 
                    source=kmeans_df)
hover = plot_kmeans.select(dict(type=HoverTool))
hover.tooltips={"cluster": "@cluster", "title": "@title"}
show(plot_kmeans)
# Out:
# /usr/local/lib/python3.4/dist-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /usr/local/lib/python3.4/dist-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)

# %% [markdown]
# Строит красивую интерактивную штуку для kmeans на LDA

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from itertools import cycle

cluster_centers_indices = af_pr_model.cluster_centers_indices_
labels = af_pr_model.labels_
n_clusters_ = len(cluster_centers_indices)

plt.close('all')
plt.figure(1)
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    class_members = labels == k
    cluster_center = X_all[cluster_centers_indices[k]]
    plt.plot(X_all[class_members, 0], X_all[class_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    for x in X_all[class_members]:
        plt.plot([cluster_center[0], x[0]], [cluster_center[1], x[1]], col)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %% [markdown]
# Пытаюсь заплотить,что получилось по AffinityPropagation,но выглядит страннно.Надо над этим думать ещё.

# %% [markdown]
# <font color=red>В общем и целом есть над чем работать, презентовать проделанную работу,а верней проиллюстировать так и не получилось и собрать воедино репрезентативный документ и параметр связности в одном  алгоритме тоже уже не успелось. Есть желание ещё поработать над точностью алгоритмов. Да и вообще, это первый подобный опыт, за эту неделю узнала столько,сколько и подумать не могла узнать,когда получила это задание.Так что в любом случае,большое спасибо :)</font>
